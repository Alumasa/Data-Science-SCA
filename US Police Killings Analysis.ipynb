# %% [markdown]
# - Import required libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - Open and read the data sets.

# %%
income = pd.read_csv('datasets/MedianHouseholdIncome2015.csv', encoding='windows-1251')

# %%
poverty = pd.read_csv('datasets/PercentagePeopleBelowPovertyLevel.csv', encoding='windows-1251')

# %%
education = pd.read_csv('datasets/PercentOver25CompletedHighSchool.csv', encoding='windows-1251')

# %%
killings = pd.read_csv('datasets/PoliceKillingsUS.csv', encoding='windows-1251')

# %%
city_race = pd.read_csv('datasets/ShareRaceByCity.csv', encoding='windows-1251')

# %%
income.head()
# Out:
#   Geographic Area             City Median Income
# 0              AL       Abanda CDP         11207
# 1              AL   Abbeville city         25615
# 2              AL  Adamsville city         42575
# 3              AL     Addison town         37083
# 4              AL       Akron town         21667

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29322 entries, 0 to 29321
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29322 non-null  object
#  1   City             29322 non-null  object
#  2   Median Income    29271 non-null  object
# dtypes: object(3)
# memory usage: 687.4+ KB

# %%
poverty.head()
# Out:
#   Geographic Area             City poverty_rate
# 0              AL       Abanda CDP         78.8
# 1              AL   Abbeville city         29.1
# 2              AL  Adamsville city         25.5
# 3              AL     Addison town         30.7
# 4              AL       Akron town           42

# %%
poverty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29329 non-null  object
#  1   City             29329 non-null  object
#  2   poverty_rate     29329 non-null  object
# dtypes: object(3)
# memory usage: 687.5+ KB

# %%
education.head()
# Out:
#   Geographic Area             City percent_completed_hs
# 0              AL       Abanda CDP                 21.2
# 1              AL   Abbeville city                 69.1
# 2              AL  Adamsville city                 78.9
# 3              AL     Addison town                 81.4
# 4              AL       Akron town                 68.6

# %%
education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geographic Area       29329 non-null  object
#  1   City                  29329 non-null  object
#  2   percent_completed_hs  29329 non-null  object
# dtypes: object(3)
# memory usage: 687.5+ KB

# %%
killings.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
killings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   int64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2526 non-null   object
#  5   age                      2458 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2340 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2470 non-null   object
#  13  body_camera              2535 non-null   bool
# dtypes: bool(2), float64(1), int64(1), object(10)
# memory usage: 242.7+ KB

# %%
city_race.head()
# Out:
#   Geographic area             City share_white share_black  \
# 0              AL       Abanda CDP        67.2        30.2
# 1              AL   Abbeville city        54.4        41.4
# 2              AL  Adamsville city        52.3        44.9
# 3              AL     Addison town        99.1         0.1
# 4              AL       Akron town        13.2        86.5
#
#   share_native_american share_asian share_hispanic
# 0                     0           0            1.6
# 1                   0.1           1            3.1
# 2                   0.5         0.3            2.3
# 3                     0         0.1            0.4
# 4                     0           0            0.3

# %%
city_race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29268 entries, 0 to 29267
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic area        29268 non-null  object
#  1   City                   29268 non-null  object
#  2   share_white            29268 non-null  object
#  3   share_black            29268 non-null  object
#  4   share_native_american  29268 non-null  object
#  5   share_asian            29268 non-null  object
#  6   share_hispanic         29268 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB

# %% [markdown]
# - I will concatenate the `income`, `poverty`, `education` and `city_race` dataframes for compact analysis.

# %%
data = pd.concat([poverty, education, income, city_race], axis=1)

# %%
data.sample(20)
# Out:
#       Geographic Area               City poverty_rate Geographic Area  \
# 966                AZ     Beaver Dam CDP         29.2              AZ
# 15390              NE      Merna village          9.8              NE
# 1080               AZ  Freedom Acres CDP            0              AZ
# 10423              LA     Covington city         18.4              LA
# 26060              TX    Study Butte CDP         41.7              TX
# 6047               ID    Warm River city            -              ID
# 8973               IA      Stanwood city            8              IA
# 4872               FL      Shalimar town          8.1              FL
# 11355              MD   Rosemont village          2.5              MD
# 9919               KY         Dixon city         11.8              KY
# 11177              MD    Huntingtown CDP          2.3              MD
# 1412               AR         Avilla CDP          1.4              AR
# 14199              MO   Leisure Lake CDP         34.1              MO
# 27264              VA       Tuckahoe CDP         10.3              VA
# 17334              NY       Houghton CDP         11.9              NY
# 9301               KS        Eureka city         15.3              KS
# 25683              TX        Orange city         21.2              TX
# 22008              PA   Fairview borough         19.5              PA
# 24519              TN    Whiteville town         45.4              TN
# 9918               KY       Diablock CDP         17.4              KY
#
#                     City percent_completed_hs Geographic Area  \
# 966       Beaver Dam CDP                   73              AZ
# 15390      Merna village                 92.5              NE
# 1080   Freedom Acres CDP                 62.3              AZ
# 10423     Covington city                 81.3              LA
# 26060    Study Butte CDP                 73.5              TX
# 6047     Warm River city                    -              ID
# 8973       Stanwood city                 89.5              IA
# 4872       Shalimar town                 98.9              FL
# 11355   Rosemont village                 96.3              MD
# 9919          Dixon city                 75.2              KY
# 11177    Huntingtown CDP                 97.6              MD
# 1412          Avilla CDP                 91.3              AR
# 14199   Leisure Lake CDP                 94.2              MO
# 27264       Tuckahoe CDP                 93.1              VA
# 17334       Houghton CDP                   97              NY
# 9301         Eureka city                 90.4              KS
# 25683        Orange city                 87.5              TX
# 22008   Fairview borough                 82.1              PA
# 24519    Whiteville town                   66              TN
# 9918        Diablock CDP                 78.6              KY
#
#                                City Median Income Geographic area  \
# 966                  Beaver Dam CDP         45078              AZ
# 15390                   Minden city         47591              NE
# 1080              Freedom Acres CDP         43472              AZ
# 10423                   Cut Off CDP         55905              LA
# 26060                   Sunray city         49716              TX
# 6047                    Weiser city         28988              ID
# 8973                 Stockport city         32019              IA
# 4872                    Sharpes CDP         43548              FL
# 11355               St. Leonard CDP        101667              MD
# 9919                Drakesboro city         46250              KY
# 11177              Indian Head town         71250              MD
# 1412                     Avilla CDP         59806              AR
# 14199  Lewis and Clark Village town         55000              MO
# 27264                  Urbanna town         37386              WA
# 17334        Huntington Bay village        177083              NY
# 9301                   Fairway city        101426              KS
# 25683                 Owl Ranch CDP           (X)              TX
# 22008              Farmersville CDP         37692              PA
# 24519                 Woodbury town         27061              TX
# 9918                     Dover city         44531              KY
#
#                        City share_white share_black share_native_american  \
# 966          Blackwater CDP         3.8         0.7                  88.2
# 15390           Nelson city        97.7           0                     0
# 1080             Gisela CDP        94.7         0.4                   2.3
# 10423      Dubberly village        90.8         8.4                     0
# 26060     Tierra Bonita CDP        51.8         4.3                     0
# 6047        Winchester city        92.1         1.2                   3.2
# 8973         Stone City CDP        97.9           1                     0
# 4872            Sneads town          78        18.5                   0.2
# 11355       Silver Hill CDP         3.9        91.5                   0.3
# 9919             Ekron city        86.7         1.5                   1.5
# 11177         Kingstown CDP        91.9         5.3                     0
# 1412           Bauxite town        94.9         1.8                   1.4
# 14199       Loma Linda town          89         2.6                   4.7
# 27264  Aberdeen Gardens CDP          91           0                   1.8
# 17334           Jericho CDP        70.8         1.9                   0.1
# 9301              Falun CDP         100           0                     0
# 25683            Perrin CDP        95.2         0.5                     0
# 22008         Franklin city        93.4         2.7                   0.3
# 24519          Annetta town        96.3         0.2                   0.9
# 9918          Edmonton city        96.2         1.8                   0.4
#
#       share_asian share_hispanic
# 966             0           22.1
# 15390           0            1.6
# 1080            0            4.4
# 10423           0            1.8
# 26060           0           95.7
# 6047          0.3            2.1
# 8973            1              0
# 4872          0.4            2.7
# 11355         0.7            3.7
# 9919          1.5            0.7
# 11177         1.2            1.8
# 1412            0            2.1
# 14199         1.1            2.8
# 27264         2.2              5
# 17334        25.4              3
# 9301            0            1.1
# 25683           1           11.1
# 22008         0.7            1.3
# 24519         0.5            3.3
# 9918          0.2            1.3

# %%
data.columns = ['area', 'city', 'poverty_rate', 'Geographic_Area_x', 'City_x',
       'education', 'Geographic_Area_y', 'City_y', 'income',
       'Geographic_area_z', 'City_z', 'share_white', 'share_black',
       'share_native_american', 'share_asian', 'share_hispanic']

# %% [markdown]
# - The cities are not the same. In this case I will perform my analysis based on geographic area.

# %%
data.drop(['Geographic_Area_x', 'City_x', 'Geographic_Area_y', 'City_y', 'Geographic_area_z', 'City_z'], 
          axis=1, inplace=True)

# %%
data.sample(20)
# Out:
#       area                    city poverty_rate education  income share_white  \
# 7277    IL         Thomson village         19.1      88.2   36513        98.7
# 16872   NY  Angola on the Lake CDP          7.6      90.3   53500        61.3
# 19540   OH       Frankfort village         13.8      81.6   35568        81.4
# 29248   WY          Marbleton town          2.2      83.2   64844        96.4
# 12134   MI      Mount Clemens city         22.3      84.5   33953        94.6
# 29323   WY              Wilson CDP          2.9       100     NaN         NaN
# 10001   KY            Guthrie city         35.7      76.9   53438        84.5
# 18794   ND           Arnegard city         26.1      86.7     (X)          95
# 16548   NM       Grenville village            0       100   35214        86.4
# 13865   MO             Cooter city          9.6      71.2   70859        96.2
# 15445   NE            Otoe village           10        99   51719          97
# 22321   PA      Larksville borough         11.7      89.2   56161        87.6
# 28855   WI          Oak Creek city          6.8      93.7       -        96.9
# 22015   PA          Farmington CDP         37.4      94.4   45333        98.8
# 884     AK           Sleetmute CDP         33.7      75.6   30313         6.4
# 5540    GA            Roswell city          9.3      93.1   38125         1.6
# 52      AL       Blue Springs town            4      95.6   45313        92.7
# 7299    IL      Troy Grove village          4.2      90.3  102554        98.6
# 20729   OK                IXL town         29.7      69.7   37917        64.2
# 16063   NJ           Heathcote CDP          6.3      96.5   71174        93.7
#
#       share_black share_native_american share_asian share_hispanic
# 7277          0.2                   0.2         0.2            0.9
# 16872        26.6                   0.1         4.9           11.8
# 19540        15.4                     0         1.5            1.3
# 29248         0.3                   0.9         0.5            2.2
# 12134         2.1                   0.6         0.7            2.4
# 29323         NaN                   NaN         NaN            NaN
# 10001        11.6                   0.2         0.5            2.3
# 18794           0                     0         1.3              0
# 16548         0.4                   0.8         0.8           29.2
# 13865           0                   0.9         0.4            2.1
# 15445           0                     0         0.3            0.3
# 22321           8                   0.1         0.6            3.7
# 28855         0.4                   0.4         0.6            1.7
# 22015         0.2                     0         0.2            0.2
# 884           1.3                  84.6           0           15.4
# 5540         97.7                   0.3           0            0.3
# 52            6.3                     0           1            3.1
# 7299          0.2                   0.3         0.3            0.6
# 20729         0.7                  24.2           0            0.3
# 16063         2.8                     0         1.4            1.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   area                   29329 non-null  object
#  1   city                   29329 non-null  object
#  2   poverty_rate           29329 non-null  object
#  3   education              29329 non-null  object
#  4   income                 29271 non-null  object
#  5   share_white            29268 non-null  object
#  6   share_black            29268 non-null  object
#  7   share_native_american  29268 non-null  object
#  8   share_asian            29268 non-null  object
#  9   share_hispanic         29268 non-null  object
# dtypes: object(10)
# memory usage: 2.2+ MB

# %%
killings
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun  53.0
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun  31.0
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun  48.0
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle  28.0
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife  32.0
#
#      gender race           city state  signs_of_mental_illness threat_level  \
# 0         M    A        Shelton    WA                     True       attack
# 1         M    W          Aloha    OR                    False       attack
# 2         M    H        Wichita    KS                    False        other
# 3         M    W  San Francisco    CA                     True       attack
# 4         M    H          Evans    CO                    False       attack
# ...     ...  ...            ...   ...                      ...          ...
# 2530      M  NaN    Kansas City    MO                    False       attack
# 2531      M  NaN    Albuquerque    NM                    False       attack
# 2532      M  NaN          Melba    ID                    False       attack
# 2533      M    B        Oshkosh    WI                    False       attack
# 2534      M    B       Brooklyn    NY                     True       attack
#
#              flee  body_camera
# 0     Not fleeing        False
# 1     Not fleeing        False
# 2     Not fleeing        False
# 3     Not fleeing        False
# 4     Not fleeing        False
# ...           ...          ...
# 2530  Not fleeing        False
# 2531          Car        False
# 2532          Car        False
# 2533          Car         True
# 2534  Not fleeing        False
#
# [2535 rows x 14 columns]

# %% [markdown]
# - Data Cleaning and Prprocessing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   area                   29329 non-null  object
#  1   city                   29329 non-null  object
#  2   poverty_rate           29329 non-null  object
#  3   education              29329 non-null  object
#  4   income                 29271 non-null  object
#  5   share_white            29268 non-null  object
#  6   share_black            29268 non-null  object
#  7   share_native_american  29268 non-null  object
#  8   share_asian            29268 non-null  object
#  9   share_hispanic         29268 non-null  object
# dtypes: object(10)
# memory usage: 2.2+ MB

# %%
#check for missing values
data.isnull().sum()
# Out:
# area                      0
# city                      0
# poverty_rate              0
# education                 0
# income                   58
# share_white              61
# share_black              61
# share_native_american    61
# share_asian              61
# share_hispanic           61
# dtype: int64

# %%
data.loc[data['income'] == '(X)'] = 0
data.loc[data['income'] == '-'] = 0

# %%
y = re.sub(r"[^0-9]", "", '3, &&33')
print(type(y))
# Out:
# <class 'str'>

# %%
import re

#data['income_col'] = data['income'].apply(lambda x: re.sub(r"[^0-9]", "", x))

for i in data['income']:
    data['income'][i] = re.sub(r"[^0-9]", "", i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-69e1db09910d> in <module>
#       4
#       5 for i in data['income']:
# ----> 6     data['income'][i] = re.sub(r"[^0-9]", "", i)
#
# C:\ProgramData\Anaconda3\lib\re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
data['income'] = data['income'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-c47c3ecf41bc> in <module>
# ----> 1 data['income'] = data['income'].astype('float')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     895     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     896         # Explicit copy, or required since NumPy can't view from / to object.
# --> 897         return arr.astype(dtype, copy=True)
#     898
#     899     return arr.view(dtype)
#
# ValueError: could not convert string to float: '2,500-'

# %%
killings.isnull().sum()
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                        9
# age                         77
# gender                       0
# race                       195
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                        65
# body_camera                  0
# dtype: int64

# %%
data['income'].describe()
# Out:
# count     29271
# unique    14592
# top           0
# freq       1113
# Name: income, dtype: int64

# %%
data[data['income'].isnull()]
# Out:
#       area                    city poverty_rate education income share_white  \
# 29119   WI       Woodville village            8        89    NaN        94.4
# 29121   WI        Wyeville village         22.4        88    NaN        93.7
# 29123   WI            Yuba village          6.3      89.7    NaN        94.4
# 29126   WY              Albany CDP            0      85.4    NaN         100
# 29129   WY             Alpine town         13.6      93.1    NaN        89.8
# 29130   WY    Alpine Northeast CDP            0       100    NaN        90.8
# 29132   WY                Alta CDP          3.5       100    NaN        94.9
# 29133   WY      Antelope Hills CDP            -         -    NaN        92.3
# 29139   WY       Atlantic City CDP            0       100    NaN        95.5
# 29140   WY              Auburn CDP          4.7       100    NaN        96.3
# 29141   WY              Baggs town          4.3        88    NaN        99.1
# 29142   WY            Bairoil town            9      93.2    NaN        92.2
# 29144   WY              Basin town          8.3      94.7    NaN          96
# 29145   WY         Bear River town          0.4      93.6    NaN        88.5
# 29152   WY             Boulder CDP            -         -    NaN         100
# 29153   WY       Boulder Flats CDP          4.9      90.7    NaN        97.8
# 29156   WY         Burlington town          4.7      94.4    NaN        91.7
# 29164   WY           Cheyenne city         11.2      93.4    NaN        96.6
# 29186   WY          Esterbrook CDP            0      85.2    NaN        94.7
# 29187   WY              Ethete CDP           19      88.7    NaN        96.8
# 29191   WY            Fairview CDP            0       100    NaN        97.6
# 29207   WY           Greybull town         13.4        83    NaN        98.7
# 29210   WY              Hanna town         30.7      88.3    NaN        90.5
# 29213   WY        Hawk Springs CDP            0      80.8    NaN        93.7
# 29217   WY          Homa Hills CDP         19.6      86.2    NaN        90.3
# 29220   WY             Huntley CDP            -         -    NaN          96
# 29225   WY           Johnstown CDP         18.6      95.5    NaN        91.4
# 29226   WY             Kaycee town          0.4        89    NaN        86.4
# 29230   WY           La Barge town          8.6      84.5    NaN          94
# 29231   WY          La Grange town         31.7      95.2    NaN        94.9
# 29232   WY      Lakeview North CDP            0       100    NaN        91.1
# 29237   WY      Little America CDP            0       100    NaN        83.1
# 29238   WY            Lonetree CDP            -         -    NaN          94
# 29242   WY               Lusk town         18.7      89.8    NaN        91.4
# 29249   WY        Meadow Acres CDP         17.6       100    NaN        93.2
# 29254   WY          Moorcroft town         10.4      95.7    NaN          87
# 29255   WY   Moose Wilson Road CDP          1.8      97.3    NaN        97.1
# 29256   WY       Mountain View CDP         27.2       100    NaN        82.7
# 29259   WY              Nordic CDP            0      97.4    NaN         100
# 29266   WY           Owl Creek CDP            -         -    NaN        97.4
# 29282   WY            Reliance CDP          7.5        83    NaN         NaN
# 29288   WY      Rolling Hills town            0      90.4    NaN         NaN
# 29297   WY               Smoot CDP            0       100    NaN         NaN
# 29300   WY  Star Valley Ranch town          4.8      88.5    NaN         NaN
# 29307   WY       Teton Village CDP            0       100    NaN         NaN
# 29308   WY             Thayne town         14.1      86.5    NaN         NaN
# 29312   WY              Upton town         15.5      92.5    NaN         NaN
# 29313   WY                Urie CDP          2.2        98    NaN         NaN
# 29315   WY             Veteran CDP            0        50    NaN         NaN
# 29317   WY          Wamsutter town          6.4      93.3    NaN         NaN
# 29321   WY          Wheatland town           12      92.7    NaN         NaN
# 29322   WY             Whiting CDP            0       100    NaN         NaN
# 29323   WY              Wilson CDP          2.9       100    NaN         NaN
# 29324   WY  Woods Landing-Jelm CDP         18.6       100    NaN         NaN
# 29325   WY            Worland city         15.3      85.6    NaN         NaN
# 29326   WY             Wright town          5.9      89.2    NaN         NaN
# 29327   WY              Yoder town          5.4      79.4    NaN         NaN
# 29328   WY           Y-O Ranch CDP            0       100    NaN         NaN
#
#       share_black share_native_american share_asian share_hispanic
# 29119         0.3                   0.8         0.2            7.6
# 29121         0.8                   3.9           0            0.8
# 29123         0.5                   0.5           0            5.6
# 29126           0                     0           0              0
# 29129         0.3                     1         0.3           12.3
# 29130         0.4                   1.7         0.4           12.5
# 29132           0                   2.2           0            5.1
# 29133           0                     0         7.7              0
# 29139         1.9                   1.9           0            7.6
# 29140         0.5                     0           0            3.7
# 29141         0.9                     0           0            7.8
# 29142         0.4                   1.2         0.7            9.5
# 29144         0.5                   0.9         0.4            4.9
# 29145         0.7                     0           0           15.1
# 29152           0                     0           0            6.5
# 29153           0                     0           0            2.2
# 29156         0.1                   0.4         1.2           13.7
# 29164           0                   1.7           0              0
# 29186           0                     0           0            9.6
# 29187           0                   1.1           0            5.3
# 29191         0.6                   0.6           0            1.8
# 29207           0                     0           0            4.6
# 29210         0.7                   0.6         1.3            9.9
# 29213         0.4                   0.6         1.2            9.4
# 29217           0                   7.3         0.8            3.6
# 29220         0.2                   0.7         1.8            2.7
# 29225           0                   0.8           0              9
# 29226         1.4                   0.8         1.1           16.4
# 29230           0                     0           0            2.4
# 29231         0.4                     1         0.9            4.3
# 29232         1.1                   5.1         0.6            9.6
# 29237         2.3                   2.1         0.4           20.4
# 29238         0.1                   0.2         0.5            5.9
# 29242         0.6                   1.8         0.6           12.8
# 29249           1                   0.9         0.5           11.3
# 29254           0                   8.7           0              0
# 29255           0                   0.3         0.1            1.9
# 29256         0.7                   2.9           0           19.7
# 29259           0                     0           0            1.9
# 29266           0                     0           0              4
# 29282         NaN                   NaN         NaN            NaN
# 29288         NaN                   NaN         NaN            NaN
# 29297         NaN                   NaN         NaN            NaN
# 29300         NaN                   NaN         NaN            NaN
# 29307         NaN                   NaN         NaN            NaN
# 29308         NaN                   NaN         NaN            NaN
# 29312         NaN                   NaN         NaN            NaN
# 29313         NaN                   NaN         NaN            NaN
# 29315         NaN                   NaN         NaN            NaN
# 29317         NaN                   NaN         NaN            NaN
# 29321         NaN                   NaN         NaN            NaN
# 29322         NaN                   NaN         NaN            NaN
# 29323         NaN                   NaN         NaN            NaN
# 29324         NaN                   NaN         NaN            NaN
# 29325         NaN                   NaN         NaN            NaN
# 29326         NaN                   NaN         NaN            NaN
# 29327         NaN                   NaN         NaN            NaN
# 29328         NaN                   NaN         NaN            NaN
